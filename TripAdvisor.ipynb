# %%
#Taipei!
import requests
from bs4 import BeautifulSoup
import sqlite3 as lite 
import sys
from datetime import date,datetime 

TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g293913-Activities-oa%d-Taipei.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0002Taipei") 
cur.execute("CREATE TABLE TW0002Taipei(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0002Taipei (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Taipei! -ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g293913-Activities-oa%d-Taipei.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0002Taipei") 
cur.execute("CREATE TABLE TWZH0002Taipei(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0002Taipei (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Xinbei
TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g1432365-Activities-oa%d-Xinbei.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0001Xinbei") 
cur.execute("CREATE TABLE TW0001Xinbei(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0001Xinbei(Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Xinbei -ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g1432365-Activities-oa%d-Xinbei.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0001Xinbei") 
cur.execute("CREATE TABLE TWZH0001Xinbei(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0001Xinbei(Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Hualien!
TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g297907-Activities-oa%d-Hualien.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0001Hualien") 
cur.execute("CREATE TABLE TW0001Hualien(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0001Hualien(Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3],row[4], datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Hualien! -ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g297907-Activities-oa%d-Hualien.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0001Hualien") 
cur.execute("CREATE TABLE TWZH0001Hualien(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0001Hualien(Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4], datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Taichung!
TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g297910-Activities-oa%d-Taichung.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.attraction_element')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, Type, attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0001Taichung") 
cur.execute("CREATE TABLE TW0001Taichung(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0001Taichung (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Taichung!-ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g297910-Activities-oa%d-Taichung.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0001Taichung") 
cur.execute("CREATE TABLE TWZH0001Taichung(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0001Taichung (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4], datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Chiayi!
TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g297904-Activities-oa%d-Chiayi.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0001Chiayi") 
cur.execute("CREATE TABLE TW0001Chiayi(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0001Chiayi (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Chiayi!-ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g297904-Activities-oa%d-Chiayi.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA',  attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0001Chiayi") 
cur.execute("CREATE TABLE TWZH0001Chiayi(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0001Chiayi (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Yilan
TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g608526-Activities-oa%d-Yilan.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking,Type,  attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0001Yilan") 
cur.execute("CREATE TABLE TW0001Yilan(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0001Yilan (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4], datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Yilan-ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g608526-Activities-oa%d-Yilan.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0001Yilan") 
cur.execute("CREATE TABLE TWZH0001Yilan(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0001Yilan (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Kaohsiung
TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g297908-Activities-oa%d-Kaohsiung.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0001Kaohsiung") 
cur.execute("CREATE TABLE TW0001Kaohsiung(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0001Kaohsiung (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Kaohsiung-ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g297908-Activities-oa%d-Kaohsiung.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0001Kaohsiung") 
cur.execute("CREATE TABLE TWZH0001Kaohsiung(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0001Kaohsiung (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Tainan
TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g293912-Activities-oa%d-Tainan.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0001Tainan") 
cur.execute("CREATE TABLE TW0001Tainan(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0001Tainan (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Tainan-ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g293912-Activities-oa%d-Tainan.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0001Tainan") 
cur.execute("CREATE TABLE TWZH0001Tainan(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0001Tainan (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Pingtung
TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g297909-Activities-oa%d-Pingtung.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0001Pingtung") 
cur.execute("CREATE TABLE TW0001Pingtung(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0001Pingtung (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Pingtung-ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g297909-Activities-oa%d-Pingtung.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0001Pingtung") 
cur.execute("CREATE TABLE TWZH0001Pingtung(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0001Pingtung (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Nantou
TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g304160-Activities-oa%d-Nantou.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0001Nantou") 
cur.execute("CREATE TABLE TW0001Nantou(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0001Nantou (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Nantou-ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g304160-Activities-oa%d-Nantou.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0001Nantou") 
cur.execute("CREATE TABLE TWZH0001Nantou(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0001Nantou (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Taoyuan
TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g297912-Activities-oa%d-Taoyuan.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0001Taoyuan") 
cur.execute("CREATE TABLE TW0001Taoyuan(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0001Taoyuan(Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Taoyuan-ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g297912-Activities-oa%d-Taoyuan.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0001Taoyuan") 
cur.execute("CREATE TABLE TWZH0001Taoyuan(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0001Taoyuan(Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Taitung
TAList = []
page_format = 'http://www.tripadvisor.com/Attractions-g304163-Activities-oa%d-Taitung.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.split('of ')[1].split(' things')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0001Taitung") 
cur.execute("CREATE TABLE TW0001Taitung(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0001Taitung(Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Taoyuan-ZH
TAList = []
page_format = 'http://www.tripadvisor.com.tw/Attractions-g304163-Activities-oa%d-Taitung.html' 
soup = BeautifulSoup(requests.get((page_format)%0).text)
finalPageText = soup.select('.entry .popRanking')[0]
finalPage = int(finalPageText.text.encode('utf-8').split('共 ')[1].split(' 個')[0])
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().encode('utf-8').replace('則評論','').replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TWZH0001Taitung") 
cur.execute("CREATE TABLE TWZH0001Taitung(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TWZH0001Taitung(Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()

# %%
#Taipei hotels!
import requests
from bs4 import BeautifulSoup
import sqlite3 as lite 
import sys
from datetime import date,datetime 

TAHotelsList = []

page_format = 'http://www.tripadvisor.com/Hotels-g293913-oa%d-Taipei-Hotels.html' 
for page in range(0, 480, 30):
    head = {"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36"}
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink,headers=head).text)
    title = soup.select('.property_details')
    for i in title:
        name = i.select('.property_title')[0].text.strip()
        print name
        links = i.findAll('a', {'href': True})
        print links[0]['href']
        img = i.select('.prw_rup .photo_image')[0]
        print img
        print img[0]['src']
        price = i.select('.headerContents .price')[0].text.strip()
        print price
# Out:
# Bouti Capsule Inn
# /Hotel_Review-g293913-d7912555-Reviews-Bouti_Capsule_Inn-Taipei.html
# <img alt="Bouti Capsule Inn" class="photo_image" height="200" id="lazyload_-1712326497_3" src="http://static.tacdn.com/img2/x.gif" style="height: 200px; width: 280px; margin-left: -60px;" width="160"/>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-7d422b27f968> in <module>()
#      21         img = i.select('.prw_rup .photo_image')[0]
#      22         print img
# ---> 23         print img[0]['src']
#      24         price = i.select('.headerContents .price')[0].text.strip()
#      25         print price
#
# /Users/May/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/bs4/element.pyc in __getitem__(self, key)
#     956         """tag[key] returns the value of the 'key' attribute for the tag,
#     957         and throws an exception if it's not there."""
# --> 958         return self.attrs[key]
#     959
#     960     def __iter__(self):
#
# KeyError: 0

# %%
for page in range(0, finalPage, 30):
    pagelink = page_format%(page) 
    soup = BeautifulSoup(requests.get(pagelink).text)
    title = soup.select('.element_wrap')
    for i in title:
        try:
            ranking = (i.select('.popRanking')[0].text.strip())
            attraction = i.select('.property_title a')[0].text.strip()
            stars = i.find('img', {'content':True})
            votes = i.select('.more a')[0].text.strip().split(' review')[0].replace(',','').strip()
            Type = i.select('.p13n_reasoning_v2')[0].text.strip()
            TAList.append([ranking, Type, attraction, stars['content'],votes])
        except:
            TAList.append([ranking, 'NA', attraction, 'NA', 'NA'])
            
            
con = lite.connect('TripAdvisor.sqlite') 
cur = con.cursor() 
#update table NAME!!!
cur.execute("DROP TABLE IF EXISTS TW0002Taipei") 
cur.execute("CREATE TABLE TW0002Taipei(Ranking Text, Type TEXT, Attraction TEXT, Stars Float, Votes INT, Date TEXT)") 
TASQL = "INSERT INTO TW0002Taipei (Ranking, Type, Attraction, Stars, Votes, Date) VALUES (?,?,?,?,?,?)"
for row in TAList:
    cur.execute(TASQL, (row[0], row[1], row[2], row[3], row[4],datetime.now().strftime("%Y-%m-%d")))
con.commit() 
con.close()
